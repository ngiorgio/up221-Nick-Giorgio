# %%
# Week 2 Assignment
# This data consists of traffic collisions in West Los Angeles
# Will help identify high injury networks

# %%
# Going to import the data set and download Pa

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import geopandas as gpd

# %%
#importing geopandas

# %%
df = gpd.read_file('Data.csv')

# %%
type(df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
df.shape
# Out:
# (13955, 19)

# %%
# shape tells us how many columns and rows are in the dataset

# %%
df.columns.to_list()
# Out:
# ['DR Number',
#  'Date Reported',
#  'Date Occurred',
#  'Time Occurred',
#  'Area ID',
#  'Area Name',
#  'Reporting District',
#  'Crime Code',
#  'Crime Code Description',
#  'MO Codes',
#  'Victim Age',
#  'Victim Sex',
#  'Victim Descent',
#  'Premise Code',
#  'Premise Description',
#  'Address',
#  'Cross Street',
#  'Location']

# %%
# columns.to_list() tells us what each column is

# %%
df.info
# Out:
# <bound method DataFrame.info of        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0      190815321    09/09/2019    09/09/2018           1445        8
# 1      170812037    06/26/2017    06/25/2017           1530        8
# 2      170813547    07/28/2017    07/28/2017           1500        8
# 3      170818830    11/21/2017    11/21/2017           1130        8
# 4      180817108    10/01/2018    09/30/2018           2210        8
# ...          ...           ...           ...            ...      ...
# 13950  190804767    01/19/2019    12/21/2018           1530        8
# 13951  190805231    01/29/2019    01/29/2018           1340        8
# 13952  190805973    02/15/2019    11/25/2018           1730        8
# 13953  190804939    01/23/2019    01/23/2018           1155        8
# 13954  190804878    01/22/2019    01/22/2018           1617        8
#
#       Area Name  Reporting District  Crime Code Crime Code Description  \
# 0       West LA                 855         997      TRAFFIC COLLISION
# 1       West LA                 893         997      TRAFFIC COLLISION
# 2       West LA                 832         997      TRAFFIC COLLISION
# 3       West LA                 841         997      TRAFFIC COLLISION
# 4       West LA                 855         997      TRAFFIC COLLISION
# ...         ...                 ...         ...                    ...
# 13950   West LA                 802         997      TRAFFIC COLLISION
# 13951   West LA                 835         997      TRAFFIC COLLISION
# 13952   West LA                 853         997      TRAFFIC COLLISION
# 13953   West LA                 813         997      TRAFFIC COLLISION
# 13954   West LA                 842         997      TRAFFIC COLLISION
#
#                                            MO Codes  Victim Age Victim Sex  \
# 0           3008 3025 3035 3037 3102 3401 3701 4027        37.0          F
# 1      3004 3028 3030 3035 3036 3101 3401 3701 4008        56.0          M
# 2      3701 3004 3028 3030 3035 3037 3101 3401 4008        48.0          M
# 3      3004 3028 3030 3035 3037 3101 3401 3701 4020        47.0          F
# 4           3035 3037 3101 3401 3701 3027 3003 4027        57.0          F
# ...                                             ...         ...        ...
# 13950       3006 3026 3035 3037 3101 3401 3701 4027        58.0          F
# 13951       3011 3028 3034 3037 3101 3401 3701 4027         NaN        NaN
# 13952       3008 3026 3035 3037 3101 3401 3701 4027        27.0          F
# 13953  3004 3028 3030 3035 3037 3101 3401 3701 4027        45.0          M
# 13954       3011 3028 3034 3037 3101 3401 3701 4008        30.0        NaN
#
#       Victim Descent  Premise Code Premise Description  \
# 0                  W           101              STREET
# 1                  A           101              STREET
# 2                  H           101              STREET
# 3                  A           101              STREET
# 4                  O           101              STREET
# ...              ...           ...                 ...
# 13950              H           108         PARKING LOT
# 13951            NaN           101              STREET
# 13952              W           101              STREET
# 13953              H           101              STREET
# 13954            NaN           101              STREET
#
#                                Address                        Cross Street  \
# 0      WESTWOOD                     BL     SANTA MONICA                 BL
# 1                             OVERLAND     SANTA MONICA                 FY
# 2      BARRINGTON                   AV  N  MAYFIELD                     RD
# 3      WILSHIRE                     BL                               BUNDY
# 4                             WESTWOOD     MASSACHUSETTS                AV
# ...                                ...                                 ...
# 13950  SUNSET                       BL     MONUMENT                     ST
# 13951  LA GRANGE                    AV     WESTWOOD                     BL
# 13952  OHIO                         AV     PURDUE                       AV
# 13953  SUNSET                       BL     CHURCH                       LN
# 13954  SAN VICENTE                  BL     SWEETZER                     ST
#
#                    Location
# 0       (34.0499, -118.437)
# 1      (34.0319, -118.4172)
# 2      (34.0518, -118.4634)
# 3      (34.0434, -118.4683)
# 4      (34.0519, -118.4388)
# ...                     ...
# 13950  (34.0461, -118.5242)
# 13951  (34.0467, -118.4341)
# 13952  (34.0473, -118.4519)
# 13953  (34.0724, -118.4674)
# 13954  (34.0465, -118.4588)
#
# [13955 rows x 18 columns]>

# %%
# info gives us the total number of crashes, adressess, victum age, and other info about the datframe

# %%
df.head(20)
# Out:
#     DR Number Date Reported Date Occurred Time Occurred Area ID Area Name  \
# 0   190815321    09/09/2019    09/09/2018          1445      08   West LA
# 1   170812037    06/26/2017    06/25/2017          1530      08   West LA
# 2   170813547    07/28/2017    07/28/2017          1500      08   West LA
# 3   170818830    11/21/2017    11/21/2017          1130      08   West LA
# 4   180817108    10/01/2018    09/30/2018          2210      08   West LA
# 5   190814307    08/17/2018    08/17/2018          1135      08   West LA
# 6   180821291    12/27/2018    12/27/2018          1620      08   West LA
# 7   180821178    12/25/2018    12/25/2018          1545      08   West LA
# 8   170814090    08/11/2017    08/11/2017          0320      08   West LA
# 9   170818105    11/08/2017    11/08/2017          1540      08   West LA
# 10  170818565    11/18/2017    11/17/2017          2130      08   West LA
# 11  180811836    06/15/2018    06/15/2018          1300      08   West LA
# 12  190804496    10/15/2018    10/15/2018          1345      08   West LA
# 13  190816518    10/04/2019    10/04/2015          1205      08   West LA
# 14  140804223    01/08/2014    01/07/2014          1825      08   West LA
# 15  170811964    06/24/2017    06/24/2017          1530      08   West LA
# 16  140805237    02/03/2014    02/02/2014          2110      08   West LA
# 17  180807016    03/07/2018    03/07/2018          1240      08   West LA
# 18  190818015    11/07/2019    11/06/2018          1655      08   West LA
# 19  160812388    07/01/2016    07/01/2016          0740      08   West LA
#
#    Reporting District Crime Code Crime Code Description  \
# 0                0855        997      TRAFFIC COLLISION
# 1                0893        997      TRAFFIC COLLISION
# 2                0832        997      TRAFFIC COLLISION
# 3                0841        997      TRAFFIC COLLISION
# 4                0855        997      TRAFFIC COLLISION
# 5                0827        997      TRAFFIC COLLISION
# 6                0841        997      TRAFFIC COLLISION
# 7                0852        997      TRAFFIC COLLISION
# 8                0836        997      TRAFFIC COLLISION
# 9                0883        997      TRAFFIC COLLISION
# 10               0819        997      TRAFFIC COLLISION
# 11               0857        997      TRAFFIC COLLISION
# 12               0853        997      TRAFFIC COLLISION
# 13               0882        997      TRAFFIC COLLISION
# 14               0819        997      TRAFFIC COLLISION
# 15               0884        997      TRAFFIC COLLISION
# 16               0841        997      TRAFFIC COLLISION
# 17               0835        997      TRAFFIC COLLISION
# 18               0847        997      TRAFFIC COLLISION
# 19               0826        997      TRAFFIC COLLISION
#
#                                         MO Codes Victim Age Victim Sex  \
# 0        3008 3025 3035 3037 3102 3401 3701 4027         37          F
# 1   3004 3028 3030 3035 3036 3101 3401 3701 4008         56          M
# 2   3701 3004 3028 3030 3035 3037 3101 3401 4008         48          M
# 3   3004 3028 3030 3035 3037 3101 3401 3701 4020         47          F
# 4        3035 3037 3101 3401 3701 3027 3003 4027         57          F
# 5   3004 3028 3030 3035 3036 3101 3401 3701 4008         28          M
# 6   3004 3028 3030 3035 3036 3104 3401 3701 4008         27          M
# 7        3004 3025 3035 3036 3101 3401 3701 4027         60          M
# 8   3003 3026 3029 3035 3036 3101 3401 3701 4008         16          F
# 9                                                        63          F
# 10       3011 3028 3030 3034 3401 3701 4027 3101         16
# 11  3008 3026 3029 3035 3036 3101 3401 3701 4027         26          M
# 12  3004 3026 3029 3035 3036 3104 3401 3701 4008
# 13  3004 3028 3030 3035 3037 3101 3401 3701 4008         36          F
# 14                                                       35          F
# 15  3004 3026 3029 3035 3036 3101 3401 3701 4027         32          F
# 16                                0605 1300 3030                     F
# 17  3003 3026 3029 3035 3037 3102 3401 3701 4027         28          M
# 18  3004 3028 3030 3035 3037 3101 3401 3701 4008         69          M
# 19  1402 3011 3035 3037 3103 3401 3701 4027 3028         15
#
#    Victim Descent Premise Code Premise Description  \
# 0               W          101              STREET
# 1               A          101              STREET
# 2               H          101              STREET
# 3               A          101              STREET
# 4               O          101              STREET
# 5               W          101              STREET
# 6               H          101              STREET
# 7               H          101              STREET
# 8               W          101              STREET
# 9               W          101              STREET
# 10                         101              STREET
# 11              W          101              STREET
# 12                         101              STREET
# 13              A          101              STREET
# 14              W          101              STREET
# 15              H          101              STREET
# 16              W          101              STREET
# 17              H          101              STREET
# 18              W          101              STREET
# 19                         101              STREET
#
#                             Address                        Cross Street  \
# 0   WESTWOOD                     BL     SANTA MONICA                 BL
# 1                          OVERLAND     SANTA MONICA                 FY
# 2   BARRINGTON                   AV  N  MAYFIELD                     RD
# 3   WILSHIRE                     BL                               BUNDY
# 4                          WESTWOOD     MASSACHUSETTS                AV
# 5   BEVERLY                      CT     SUNSET                       BL
# 6                      SANTA MONICA                             SALTAIR
# 7   SANTA MONICA                 BL     WESTGATE                     AV
# 8   SANTA MONICA                 BL     BEVERLY GLEN                 BL
# 9   PONTIUS                      AV     OLYMPIC                      BL
# 10  BEL AIR                      RD     BEL AIR                      CT
# 11  GLENVILLE                    DR     PICO                         BL
# 12  NATIONAL                     BL                            OVERLAND
# 13  SAWTELLE                     BL     OLYMPIC                      BL
# 14  BEVERLY GLEN                 BL     COMSTOCK                     AV
# 15                          GLENDON                             OLYMPIC
# 16  CENTINELA                    AV     MCCLELLAN                    DR
# 17  WESTWOOD                     BL     OLYMPIC                      BL
# 18  KERWOOD                      AV     PICO                         BL
# 19  GRANVILLE                    AV     SUNSET                       BL
#
#                 Location geometry
# 0    (34.0499, -118.437)     None
# 1   (34.0319, -118.4172)     None
# 2   (34.0518, -118.4634)     None
# 3   (34.0434, -118.4683)     None
# 4   (34.0519, -118.4388)     None
# 5   (34.0638, -118.4703)     None
# 6   (34.0406, -118.4633)     None
# 7   (34.0424, -118.4592)     None
# 8   (34.0568, -118.4247)     None
# 9   (34.0399, -118.4385)     None
# 10  (34.0737, -118.4289)     None
# 11  (34.0553, -118.3928)     None
# 12  (34.0445, -118.4491)     None
# 13  (34.0382, -118.4412)     None
# 14  (34.0735, -118.4315)     None
# 15  (34.0444, -118.4308)     None
# 16  (34.0403, -118.4696)     None
# 17  (34.0439, -118.4317)     None
# 18  (34.0474, -118.4153)     None
# 19  (34.0612, -118.4706)     None

# %%
# shows us the first 15 rows

# %%
df.tail(1)
# Out:
#        DR Number Date Reported Date Occurred Time Occurred Area ID Area Name  \
# 13954  190804878    01/22/2019    01/22/2018          1617      08   West LA
#
#       Reporting District Crime Code Crime Code Description  \
# 13954               0842        997      TRAFFIC COLLISION
#
#                                       MO Codes Victim Age Victim Sex  \
# 13954  3011 3028 3034 3037 3101 3401 3701 4008         30
#
#       Victim Descent Premise Code Premise Description  \
# 13954                         101              STREET
#
#                                Address                     Cross Street  \
# 13954  SAN VICENTE                  BL  SWEETZER                     ST
#
#                    Location geometry
# 13954  (34.0465, -118.4588)     None

# %%
# tail shows the last row in df

# %%
df.sample(4)
# Out:
#        DR Number Date Reported Date Occurred Time Occurred Area ID Area Name  \
# 12486  180813548    07/20/2018    07/20/2018          2330      08   West LA
# 12329  180810235    05/09/2018    05/09/2018          1145      08   West LA
# 304    140806685    03/15/2014    03/15/2014          0930      08   West LA
# 10773  170815924    09/22/2017    09/22/2017          1005      08   West LA
#
#       Reporting District Crime Code Crime Code Description  \
# 12486               0815        997      TRAFFIC COLLISION
# 12329               0882        997      TRAFFIC COLLISION
# 304                 0814        997      TRAFFIC COLLISION
# 10773               0882        997      TRAFFIC COLLISION
#
#                                            MO Codes Victim Age Victim Sex  \
# 12486  3011 3026 3029 3035 3036 3101 3401 3701 4008
# 12329  3006 3028 3030 3035 3037 3101 3401 3701 4008         24          M
# 304              3011 3034 3037 3101 3401 3701 4027         99
# 10773       3004 3026 3035 3036 3101 3401 3701 4027         53          M
#
#       Victim Descent Premise Code Premise Description  \
# 12486                         101              STREET
# 12329              W          101              STREET
# 304                           102            SIDEWALK
# 10773              W          101              STREET
#
#                                   Address                     Cross Street  \
# 12486     SUNSET                       BL  VETERAN                      AV
# 12329     CORINTH                      AV  OLYMPIC                      BL
# 304    N  CHURCH                       LN  SUNSET                       BL
# 10773     PICO                         BL  CORINTH                      AV
#
#                    Location geometry
# 12486  (34.0759, -118.4555)     None
# 12329  (34.0376, -118.4422)     None
# 304    (34.0711, -118.4656)     None
# 10773  (34.0347, -118.4397)     None

# %%
# gives us randam sample of 4

# %%
df.dtypes
# Out:
# DR Number                   object
# Date Reported               object
# Date Occurred               object
# Time Occurred               object
# Area ID                     object
# Area Name                   object
# Reporting District          object
# Crime Code                  object
# Crime Code Description      object
# MO Codes                    object
# Victim Age                  object
# Victim Sex                  object
# Victim Descent              object
# Premise Code                object
# Premise Description         object
# Address                     object
# Cross Street                object
# Location                    object
# geometry                  geometry
# dtype: object

# %%
df.columns.to_list()
# Out:
# ['DR Number',
#  'Date Reported',
#  'Date Occurred',
#  'Time Occurred',
#  'Area ID',
#  'Area Name',
#  'Reporting District',
#  'Crime Code',
#  'Crime Code Description',
#  'MO Codes',
#  'Victim Age',
#  'Victim Sex',
#  'Victim Descent',
#  'Premise Code',
#  'Premise Description',
#  'Address',
#  'Cross Street',
#  'Location',
#  'geometry']

# %%
df['Location'].sample(5)
# Out:
# 8434     (34.0314, -118.4593)
# 13048    (34.0426, -118.3764)
# 12431    (34.0548, -118.3837)
# 12645    (34.0495, -118.4481)
# 1085      (34.0328, -118.442)
# Name: Location, dtype: object

# %%
#sample with 5 random cordinates

# %%
df['Location'].value_counts()
# Out:
# Location
# (34.0401, -118.5606)    111
# (34.043, -118.5398)     107
# (34.0382, -118.4412)    103
# (34.0578, -118.4478)     96
# (34.0465, -118.4484)     75
#                        ...
# (34.053, -118.4818)       1
# (34.0469, -118.5242)      1
# (34.0489, -118.536)       1
# (34.0508, -118.4683)      1
# (34.0565, -118.4291)      1
# Name: count, Length: 2196, dtype: int64

# %%
#Location values, looks like it shows the top five locations and lowest as well

# %%
location_count = df['Location'].value_counts()
location_count
# Out:
# Location
# (34.0401, -118.5606)    111
# (34.043, -118.5398)     107
# (34.0382, -118.4412)    103
# (34.0578, -118.4478)     96
# (34.0465, -118.4484)     75
#                        ...
# (34.053, -118.4818)       1
# (34.0469, -118.5242)      1
# (34.0489, -118.536)       1
# (34.0508, -118.4683)      1
# (34.0565, -118.4291)      1
# Name: count, Length: 2196, dtype: int64

# %%
type(location_count)
# Out:
# pandas.core.series.Series

# %%
location_count =location_count.reset_index()
location_count
# Out:
#                   Location  count
# 0     (34.0401, -118.5606)    111
# 1      (34.043, -118.5398)    107
# 2     (34.0382, -118.4412)    103
# 3     (34.0578, -118.4478)     96
# 4     (34.0465, -118.4484)     75
# ...                    ...    ...
# 2191   (34.053, -118.4818)      1
# 2192  (34.0469, -118.5242)      1
# 2193   (34.0489, -118.536)      1
# 2194  (34.0508, -118.4683)      1
# 2195  (34.0565, -118.4291)      1
#
# [2196 rows x 2 columns]

# %%
#changes the way rows are labeled

# %%
type(location_count)
# Out:
# pandas.core.frame.DataFrame

# %%
location_count.columns.to_list()
# Out:
# ['Location', 'count']

# %%
location_count.columns = ['location' , 'count']
location_count
# Out:
#                   location  count
# 0     (34.0401, -118.5606)    111
# 1      (34.043, -118.5398)    107
# 2     (34.0382, -118.4412)    103
# 3     (34.0578, -118.4478)     96
# 4     (34.0465, -118.4484)     75
# ...                    ...    ...
# 2191   (34.053, -118.4818)      1
# 2192  (34.0469, -118.5242)      1
# 2193   (34.0489, -118.536)      1
# 2194  (34.0508, -118.4683)      1
# 2195  (34.0565, -118.4291)      1
#
# [2196 rows x 2 columns]

# %%
location_count.plot()
# Out:
# <Axes: >

# %%
location_count.plot.bar(x = 'location', y = 'count', title = 'Number collsions by location')
# Out:
# <Axes: title={'center': 'Number collsions by location'}, xlabel='location'>

# %%
# This one looks crazy, way to much data. Idk bruh

# %%
df_trimmed.Location
# Out:
# 0         (34.0499, -118.437)
# 1        (34.0319, -118.4172)
# 2        (34.0518, -118.4634)
# 3        (34.0434, -118.4683)
# 4        (34.0519, -118.4388)
#                  ...
# 13950    (34.0461, -118.5242)
# 13951    (34.0467, -118.4341)
# 13952    (34.0473, -118.4519)
# 13953    (34.0724, -118.4674)
# 13954    (34.0465, -118.4588)
# Name: Location, Length: 13955, dtype: object

# %%
# Data needs cleaning so the plot makes no sense lol. Was trying to figure out how to omit variable, was getting pretty close but gave up :/

# %%
desired_columns = ['Victim Age']

# %%
df_trimmed = df [desired_columns].copy()
df_trimmed
# Out:
#        Victim Age
# 0            37.0
# 1            56.0
# 2            48.0
# 3            47.0
# 4            57.0
# ...           ...
# 13950        58.0
# 13951         NaN
# 13952        27.0
# 13953        45.0
# 13954        30.0
#
# [13955 rows x 1 columns]

# %%
#singled out the collsion party's age

# %%
age = df['Victim Age'].value_counts()
age
# Out:
# Victim Age
# 30.0    391
# 28.0    369
# 27.0    352
# 25.0    342
# 26.0    340
#        ...
# 92.0      3
# 93.0      2
# 91.0      2
# 15.0      1
# 97.0      1
# Name: count, Length: 82, dtype: int64

# %%
df_trimmed.plot()
# Out:
# <Axes: >

# %%
# Still looks insane haha
