# %%
#Week 3 Group Assignment 2
#Census Data Exploration
#Name: Nick Giorgio
#This data shows houshold income, specifically housholds making over 200,000

# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('census.csv')
df
# Out:
#         Geo_FIPS                                          Geo_QName  \
# 0     6037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 1     6037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 2     6037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 3     6037101221  Census Tract 1012.21, Los Angeles County, Cali...
# 4     6037101222  Census Tract 1012.22, Los Angeles County, Cali...
# ...          ...                                                ...
# 2493  6037980038  Census Tract 9800.38, Los Angeles County, Cali...
# 2494  6037980039  Census Tract 9800.39, Los Angeles County, Cali...
# 2495  6037990100  Census Tract 9901, Los Angeles County, California
# 2496  6037990200  Census Tract 9902, Los Angeles County, California
# 2497  6037990300  Census Tract 9903, Los Angeles County, California
#
#      Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#All data

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.sample()
# Out:
#         Geo_FIPS                                          Geo_QName  \
# 1051  6037291300  Census Tract 2913, Los Angeles County, California
#
#      Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION  \
# 1051         ca         140            0     NaN         NaN           NaN
#
#       Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  \
# 1051          6          37         NaN        NaN     291300         NaN
#
#       Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  Geo_AITS  Geo_ANRC  \
# 1051         NaN         NaN           NaN          NaN       NaN       NaN
#
#       Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  \
# 1051       NaN      NaN         NaN       NaN       NaN        NaN
#
#       Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_CDCURR  Geo_SLDU  Geo_SLDL  \
# 1051         NaN           NaN     NaN         NaN       NaN       NaN
#
#       Geo_ZCTA3  Geo_ZCTA5  Geo_SUBMCD  Geo_SDELM  Geo_SDSEC  Geo_SDUNI  \
# ...

# %%
#convert to string

# %%
df = pd.read_csv(
    'census.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 78 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2498 non-null   object
#  1   Geo_QName          2498 non-null   object
#  2   Geo_STUSAB         2498 non-null   object
#  3   Geo_SUMLEV         2498 non-null   int64
#  4   Geo_GEOCOMP        2498 non-null   int64
#  5   Geo_US             0 non-null      float64
#  6   Geo_REGION         0 non-null      float64
#  7   Geo_DIVISION       0 non-null      float64
#  8   Geo_STATE          2498 non-null   object
#  9   Geo_COUNTY         2498 non-null   object
#  10  Geo_COUSUB         0 non-null      float64
#  11  Geo_PLACE          0 non-null      float64
#  12  Geo_TRACT          2498 non-null   int64
#  13  Geo_BLKGRP         0 non-null      float64
#  14  Geo_CONCIT         0 non-null      float64
#  15  Geo_AIANHH         0 non-null      float64
# ...

# %%
#find null and delete them

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_PUMA5',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           2498 non-null   object
#  1   Geo_QName          2498 non-null   object
#  2   Geo_STUSAB         2498 non-null   object
#  3   Geo_SUMLEV         2498 non-null   int64
#  4   Geo_GEOCOMP        2498 non-null   int64
#  5   Geo_STATE          2498 non-null   object
#  6   Geo_COUNTY         2498 non-null   object
#  7   Geo_TRACT          2498 non-null   int64
#  8   Geo_NAME           2498 non-null   object
#  9   SE_A14001_001      2498 non-null   int64
#  10  SE_A14001_002      2498 non-null   int64
#  11  SE_A14001_003      2498 non-null   int64
#  12  SE_A14001_004      2498 non-null   int64
#  13  SE_A14001_005      2498 non-null   int64
#  14  SE_A14001_006      2498 non-null   int64
#  15  SE_A14001_007      2498 non-null   int64
# ...

# %%
columns_to_keep = ['Geo_FIPS',
                   'SE_A14001_001',
                   'SE_A14001_002',
                   'SE_A14001_003',
                   'SE_A14001_004',
                   'SE_A14001_005',
                   'SE_A14001_006',
                   'SE_A14001_007',
                   'SE_A14001_008',
                   'SE_A14001_009',
                   'SE_A14001_010',
                   'SE_A14001_011',
                   'SE_A14001_012',
                   'SE_A14001_013',
                   'SE_A14001_014',
                   'SE_A14001_015',
                   'SE_A14001_016',
                   'SE_A14001_017']

# %%
df2 = df[columns_to_keep]

# %%
columns = list(df2) 
columns
# Out:
# ['Geo_FIPS',
#  'SE_A14001_001',
#  'SE_A14001_002',
#  'SE_A14001_003',
#  'SE_A14001_004',
#  'SE_A14001_005',
#  'SE_A14001_006',
#  'SE_A14001_007',
#  'SE_A14001_008',
#  'SE_A14001_009',
#  'SE_A14001_010',
#  'SE_A14001_011',
#  'SE_A14001_012',
#  'SE_A14001_013',
#  'SE_A14001_014',
#  'SE_A14001_015',
#  'SE_A14001_016',
#  'SE_A14001_017']

# %%
df2.columns = ['FIPS',
'Total_Household',
'Less than $10,000',
'$10,000 to $14,999',
'$15,000 to $19,999',
'$20,000 to $24,999',
'$25,000 to $29,999',
'$30,000 to $34,999',
'$35,000 to $39,999',
'$40,000 to $44,999',
'$45,000 to $49,999',
'$50,000 to $59,999',
'$60,000 to $74,999',
'$75,000 to $99,999',
'$100,000 to $124,999',
'$125,000 to $149,999',
'$150,000 to $199,999',
'$200,000 or More']

# %%
#Number of housholds making 200,000 or more

# %%
df2['$200,000 or More'].describe()
# Out:
# count    2498.000000
# mean      200.699359
# std       214.194526
# min         0.000000
# 25%        48.000000
# 50%       126.000000
# 75%       284.750000
# max      1971.000000
# Name: $200,000 or More, dtype: float64

# %%
df2['$200,000 or More'].plot()
# Out:
# <Axes: >

# %%
df2.plot.scatter(x='$200,000 or More',y='$10,000 to $14,999')
# Out:
# <Axes: xlabel='$200,000 or More', ylabel='$10,000 to $14,999'>

# %%
tracts=gpd.read_file('Census_Tracts_2020.geojson')

# %%
tracts.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %%
tracts_income=tracts.merge(df2,on="FIPS")

# %%
tracts_income.plot(figsize=(12,10),
                 column='$200,000 or More',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
#Households making over $200,000

# %%
tracts_income.plot(figsize=(12,10),
                 column='$200,000 or More',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >
